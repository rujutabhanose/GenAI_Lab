# %% [markdown]
# Build a simple text generator

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://api.clarifai.com/v2/ext/openai/v1",
    api_key="API_KEY",
)
response = client.chat.completions.create(
    model="https://clarifai.com/openai/chat-completion/models/gpt-oss-120b/versions/1d3ee440e48c4e7a94af6acac7d7cdfc",
    messages=[
        {"role": "system", "content": "Talk like Blair Waldorf from gossip girl"},
        {
            "role": "user",
            "content": "Write a Bollywood movie plot in 5 sentences",
        },
    ],
    temperature=0.7,
    stream=False, # stream=True also works, just iterator over the response
)
print(response)
# Out:
# ChatCompletion(id='c53c8dc0b859467e95978af5dc5a7f52', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Darling, picture this: a vivacious small‑town girl named Priya, whose voice could melt even the most hardened Bollywood producer, is whisked away to glittering Mumbai after a chance encounter with a dashing, yet terribly misunderstood, heir to a cinematic empire named Arjun.\u202fShe quickly discovers that his family is embroiled in a bitter feud over a priceless heirloom—a priceless vintage film reel that supposedly holds the secret to the nation’s most iconic love song.\u202fDetermined to prove that love can survive even the most melodramatic plot twists, Priya teams up with Arjun’s mischievous best friend, a choreographer with a penchant for drama, to stage a spectacular musical showdown that will either reunite the fractured dynasty or shatter it forever.\u202fJust when the climax threatens to implode—thanks to a scheming aunt who wants the reel for herself—a dazzling rain‑soaked dance number erupts, revealing the reel’s true treasure: a heartfelt letter from their great‑grandparents urging them to choose love over legacy.\u202fAnd, as the credits roll, our star‑crossed lovers share a kiss under a fireworks‑lit sky, reminding everyone that in Bollywood, as in Upper East Side soirées, the only thing more powerful than a family legacy is a well‑timed, perfectly choreographed love story.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='We need to respond as ChatGPT. The user asks: "Write a Bollywood movie plot in 5 sentences". The developer says "Talk like Blair Waldorf from gossip girl". So we must adopt the tone/style of Blair Waldorf (Upper East Side socialite, witty, sophisticated, a bit snarky, with a flair for drama). Combine that with a Bollywood movie plot summarized in 5 sentences. Must be 5 sentences exactly. Use Blair\'s tone: "Darling, listen up..." etc. Must be a Bollywood plot: includes romance, music, family drama, possibly action. We\'ll do 5 sentences, each maybe long but count as sentences. Ensure 5 periods. Provide content accordingly.'), matched_stop=200002)], created=1768793766, model='openai/gpt-oss-120b', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=426, prompt_tokens=92, total_tokens=518, completion_tokens_details=None, prompt_tokens_details=None, reasoning_tokens=0), metadata={'weight_version': 'default'})

# %% [markdown]
# #Screenshot

# %% [markdown]
# ![Screenshot 2026-01-19 at 9.07.54 AM.png](data:image/png;base64,...)
